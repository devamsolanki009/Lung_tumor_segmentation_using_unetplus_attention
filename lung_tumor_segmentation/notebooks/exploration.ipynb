# %% [markdown]
# # Exploration Notebook
#
# Use this notebook for interactive data exploration and prototyping.
#
# **This notebook is NOT part of the production pipeline.**
# Use `main.py --all` for the full pipeline, or individual `scripts/run_*.py` scripts.
#
# The original monolithic notebook has been preserved at:
# `notebooks/legacy_notebook.ipynb`

# %%
import sys
from pathlib import Path

# Add repo root to path
repo_root = Path('.').resolve().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from lung_tumor_segmentation.config.loader import load_config
cfg = load_config()
print('Config loaded:', list(cfg.keys()))
